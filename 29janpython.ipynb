# %% [markdown]
# Who developed Python Programming Language?
#
# Python was developed by Guido van Rossum.
#
# Which type of Programming does Python support?
#
# Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming.
#
# Is Python case sensitive when dealing with identifiers?
#
# Yes, Python is case-sensitive when dealing with identifiers.
#
# What is the correct extension of the Python file?
#
# The correct extension is .py.
#
# Is Python code compiled or interpreted?
#
# Python is interpreted.
#
# Name a few blocks of code used to define in Python language?
#
# Functions (def)
#
# Classes (class)
#
# Conditional statements (if, elif, else)
#
# Loops (for, while)
#
# State a character used to give single-line comments in Python?
#
# The # character is used for single-line comments.
#
# Mention functions which can help us to find the version of Python that we are currently working on?
#
# sys.version
#
# platform.python_version()
#
# python --version (from command line)
#
# Python supports the creation of anonymous functions at runtime, using a construct called
# lambda.
#
# What does pip stand for Python?
#
# pip stands for "Pip Installs Packages".
#
# Mention a few built-in functions in Python?
#
# print()
#
# len()
#
# type()
#
# input()
#
# sum()
# What is the maximum possible length of an identifier in Python?
#
# There is no fixed limit on the length of an identifier in Python, but it is generally advisable to keep it manageable.
#
# What are the benefits of using Python?
#
# Easy to read and write
#
# Supports multiple paradigms
#
# Large standard library
#
# Cross-platform
#
# Dynamic typing
#
# Huge community support
#
# How is memory managed in Python?
#
# Memory is managed by the Python Memory Manager, with mechanisms such as garbage collection to free unused memory.
#
# How to install Python on Windows and set path variables?
#
# Download Python from the official website (python.org).
#
# Install it and check the option to "Add Python to PATH" during installation.
#
# After installation, verify by running python --version in the command prompt.
#
# Is indentation required in Python?
#
# Yes, indentation is required to define blocks of code in Python.
